# %% [markdown]
# <a href="https://colab.research.google.com/github/bithu-learn/ML-Training-NTT-1/blob/main/ml_day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("PANDAS")
# Out:
# PANDAS

# %%
import pandas as pd
# list
l = [[[10,20,30,40,50],[100,200,300,400,500,600]],[[100,200,300,400,500,600],[10,20,30,40,50]]]

df = pd.DataFrame(l,index =["a","b"],columns=["c","d"] )

print(df)
# Out:
#                                 c                               d
# a            [10, 20, 30, 40, 50]  [100, 200, 300, 400, 500, 600]
# b  [100, 200, 300, 400, 500, 600]            [10, 20, 30, 40, 50]

# %%
data = {"calories":[420,380,390],"duration":[50,40,45]}

df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
from numpy.random import randn
import numpy as np
np.random.seed(101)
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns=["W","x","y","z"])
df
# Out:
#           W         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['x']
# Out:
# A    0.628133
# B   -0.319318
# C    0.740122
# D   -0.758872
# E    1.978757
# Name: x, dtype: float64

# %%
df[['x','z']]
# Out:
#           x         z
# A  0.628133  0.503826
# B -0.319318  0.605965
# C  0.740122 -0.589001
# D -0.758872  0.955057
# E  1.978757  0.683509

# %%
df['n']=df['x'] + df['z']
df
# Out:
#           W         x         y         z         n
# A  2.706850  0.628133  0.907969  0.503826  1.131958
# B  0.651118 -0.319318 -0.848077  0.605965  0.286647
# C -2.018168  0.740122  0.528813 -0.589001  0.151122
# D  0.188695 -0.758872 -0.933237  0.955057  0.196184
# E  0.190794  1.978757  2.605967  0.683509  2.662266

# %%
df.drop('n',axis=1,inplace =True)

# %%
df
# Out:
#           W         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
#Rows

df.loc['A']
# Out:
# W    2.706850
# x    0.628133
# y    0.907969
# z    0.503826
# Name: A, dtype: float64

# %%
df.iloc[0]
# Out:
# W    2.706850
# x    0.628133
# y    0.907969
# z    0.503826
# Name: A, dtype: float64

# %%
#subset

df
# Out:
#           W         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.loc['C','y']
# Out:
# 0.5288134940893595

# %%
df.loc[['B','C'],['W','x','z','y']]
# Out:
#           W         x         z         y
# B  0.651118 -0.319318  0.605965 -0.848077
# C -2.018168  0.740122 -0.589001  0.528813

# %%
# conditional selection
df
# Out:
#           W         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df > 0
# Out:
#        W      x      y      z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df[df>0]
# Out:
#           W         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
dd=df[df['W']>0]
print(dd)
print(type(dd))
# Out:
#           W         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509
# <class 'pandas.core.frame.DataFrame'>

# %%
dd =  df[df['W']>0][['y','z']]
print(dd)
# Out:
#           y         z
# A  0.907969  0.503826
# B -0.848077  0.605965
# D -0.933237  0.955057
# E  2.605967  0.683509

# %%
df
# Out:
#           W         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
dd2 = df[(df['W']>0) & (df['y']>1)]

print(dd2)
# Out:
#           W         x         y         z
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index(inplace= True)
df
# Out:
#   index         W         x         y         z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
df = pd.read_csv('data 1.csv')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows=1000

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.head(25)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112       NaN
# 18        60    103       123     323.0
# 19        45     97       125     243.0
# 20        60    108       131     364.2
# 21        45    100       119     282.0
# ...

# %%
df.tail(10)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %%
six_point_summ = df.describe()

# %%
six_point_summ
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
dirty_df = pd.read_csv('dirtydata.csv')
print(dirty_df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
print(dirty_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB
# None

# %%
dirty_df.describe()

# %%
dirty_df.describe(include=['O'])
# Out:
#                 Date
# count             31
# unique            30
# top     '2020/12/12'
# freq               2

# %%
#cleaning data
#dropping the NaN Values
x = dirty_df.dropna()
print(x)
print(type(x))

# %%
#actual removal of data from dirty_df
dirty_df.dropna(inplace = True)
print(dirty_df)

# %%
dirty_df

# %%
x = dirty_df['Calories'].mean()
print(x)

# %%
#Note : reset the df when trying diffrenet ways to fillna
dirty_df['Calories'].fillna(x,inplace = True)
print(dirty_df)

# %%
#filling calories with mean
#Note : reset the df when trying diffrenet ways to fillna
dirty_df.fillna({'Calories':x},inplace = True)
print(dirty_df)

# %%
med = df['Calories'].median()
print(med)

# %%
#filling calories with median
#Note : reset the df when trying diffrenet ways to fillna
dirty_df.fillna({'Calories':med},inplace = True)
print(dirty_df)

# %%
mod = df['Calories'].mode()[0]
print(x)

# %%
#filling calories with mode
#Note : reset the df when trying diffrenet ways to fillna
dirty_df.fillna({'Calories':mod},inplace = True)
print(dirty_df)

# %%
#correcting date format, check row# 26
dirty_df['Date'] = pd.to_datetime(dirty_df['Date'], format='mixed')
print(dirty_df)

# %%
#Remove row#22 from dataset as it has no date value
# Here we are only removing NaN col of 'Date' Col
dirty_df.dropna(subset=['Date'],inplace = True)
print(dirty_df)

# %%
Check row#7
for x in dirty_df.index:
  if dirty_df.loc[x, "Duration"] > 70:
    dirty_df.loc[x, "Duration"] = 70
print(dirty_df)

# %%
#we can also drop the outlier row #7
print(dirty_df)
for x in dirty_df.index:
  if dirty_df.loc[x, "Duration"] > 70:
    dirty_df.drop(x, inplace = True)
print(dirty_df)

# %%
dirty_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
dirty_df.drop_duplicates(inplace=True)

# %%
dirty_df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...
